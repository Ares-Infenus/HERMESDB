# %%
valor_b = diccionario_datos['crypto']['BTCUSD']['1H']['BTCUSD_1H_ASK']
print(valor_b)
# Out:
#                              Local time    Open    High     Low   Close  \
# 0      01.08.2017 00:00:00.000 GMT-0500    2885    2928    2863    2904
# 1      01.08.2017 01:00:00.000 GMT-0500    2904    2915    2850    2860
# 2      01.08.2017 02:00:00.000 GMT-0500    2861    2881    2768    2776
# 3      01.08.2017 03:00:00.000 GMT-0500    2776    2842    2673    2710
# 4      01.08.2017 04:00:00.000 GMT-0500    2712    2772    2690    2740
# ...                                 ...     ...     ...     ...     ...
# 64627  14.12.2024 19:00:00.000 GMT-0500  101463  101613  101287  101491
# 64628  14.12.2024 20:00:00.000 GMT-0500  101485  102219  101457  102154
# 64629  14.12.2024 21:00:00.000 GMT-0500  102154  102171  101802  101855
# 64630  14.12.2024 22:00:00.000 GMT-0500  101856  101981  101761  101771
# 64631  14.12.2024 23:00:00.000 GMT-0500  101771  102870  101771  102411
#
#          Volume
# 0      184.9375
# 1      165.3635
# 2      186.3393
# 3      216.6280
# 4      147.5201
# ...         ...
# 64627    0.0049
# 64628    0.0046
# 64629    0.0058
# 64630    0.0035
# 64631    0.0124
#
# [64632 rows x 6 columns]

# %%
import os
import pandas as pd

def cargar_dataframes(carpeta_base):
    estructura = {}

    for root, dirs, files in os.walk(carpeta_base):
        # Obtener la ruta relativa desde la carpeta base
        ruta_relativa = os.path.relpath(root, carpeta_base)
        partes_ruta = ruta_relativa.split(os.sep)

        # Navegar a través del diccionario para llegar a la ubicación correcta
        actual = estructura
        for parte in partes_ruta:
            if parte not in actual:
                actual[parte] = {}
            actual = actual[parte]

        # Cargar los archivos CSV en la ubicación correcta del diccionario
        for file in files:
            if file.endswith('.csv'):
                nombre_archivo = os.path.splitext(file)[0]
                ruta_completa = os.path.join(root, file)
                actual[nombre_archivo] = pd.read_csv(ruta_completa)

    return estructura

# Ruta de la carpeta base
carpeta_base = 'C:\\Users\\spinz\\Documents\\Portafolio Oficial\\HERMESDB\\data\\raw'

# Cargar los dataframes
diccionario_datos = cargar_dataframes(carpeta_base)

# %%
def describir_estructura(diccionario, nivel=0):
    for clave, valor in diccionario.items():
        if isinstance(valor, pd.DataFrame):
            print('│   ' * nivel + '├── ' + clave + '.csv')  # Assuming CSV for simplicity
        else:
            print('│   ' * nivel + '├── ' + clave + '/')
            if isinstance(valor, dict):
                describir_estructura(valor, nivel + 1)

# Llamar a la función con el diccionario de datos
describir_estructura(diccionario_datos)
# Out:
# ├── ./
# ├── crypto/
# │   ├── BTCUSD/
# │   │   ├── 1D/
# │   │   │   ├── BTCUSD_1D_ASK.csv
# │   │   │   ├── BTCUSD_1D_BID.csv
# │   │   ├── 1H/
# │   │   │   ├── BTCUSD_1H_ASK.csv
# │   │   │   ├── BTCUSD_1H_BID.csv
# │   │   ├── 1M/
# │   │   │   ├── BTCUSD_1M_ASK.csv
# │   │   │   ├── BTCUSD_1M_BID.csv
# │   │   ├── 1W/
# │   │   │   ├── BTCUSD_1W_ASK.csv
# │   │   │   ├── BTCUSD_1W_BID.csv
# │   │   ├── 4H/
# │   │   │   ├── BTCUSD_4H_ASK.csv
# │   │   │   ├── BTCUSD_4H_BID.csv
# ├── forex/
# │   ├── EURUSD/
# │   │   ├── 1D/
# │   │   │   ├── EURUSD_1D_ASK.csv
# │   │   │   ├── EURUSD_1D_BID.csv
# │   │   ├── 1H/
# │   │   │   ├── EURUSD_1H_ASK.csv
# │   │   │   ├── EURUSD_1H_BID.csv
# │   │   ├── 1M/
# │   │   │   ├── EURUSD_1M_ASK.csv
# │   │   │   ├── EURUSD_1M_BID.csv
# │   │   ├── 1W/
# │   │   │   ├── EURUSD_1W_ASK.csv
# │   │   │   ├── EURUSD_1W_BID.csv
# │   │   ├── 4H/
# │   │   │   ├── EURUSD_4H_ASK.csv
# │   │   │   ├── EURUSD_4H_BID.csv
# │   ├── GBPUSD/
# │   │   ├── 1D/
# │   │   │   ├── GBPUSD_1D_ASK.csv
# │   │   │   ├── GBPUSD_1D_BID.csv
# │   │   ├── 1H/
# │   │   │   ├── GBPUSD_1H_ASK.csv
# │   │   │   ├── GBPUSD_1H_BID.csv
# │   │   ├── 1M/
# │   │   │   ├── GBPUSD_1M_ASK.csv
# │   │   │   ├── GBPUSD_1M_BID.csv
# │   │   ├── 1W/
# │   │   │   ├── GBPUSD_1W_ASK.csv
# │   │   │   ├── GBPUSD_1W_BID.csv
# │   │   ├── 4H/
# │   │   │   ├── GBPUSD_4H_ASK.csv
# │   │   │   ├── GBPUSD_4H_BID.csv
# │   ├── USDJPY/
# │   │   ├── 1D/
# │   │   │   ├── USDJPY_1D_ASK.csv
# │   │   │   ├── USDJPY_1D_BID.csv
# │   │   ├── 1H/
# │   │   │   ├── USDJPY_1H_ASK.csv
# │   │   │   ├── USDJPY_1H_BID.csv
# │   │   ├── 1M/
# │   │   │   ├── USDJPY_1M_ASK.csv
# │   │   │   ├── USDJPY_1M_BID.csv
# │   │   ├── 1W/
# │   │   │   ├── USDJPY_1W_ASK.csv
# │   │   │   ├── USDJPY_1W_BID.csv
# │   │   ├── 4H/
# │   │   │   ├── USDJPY_4H_ASK.csv
# │   │   │   ├── USDJPY_4H_BID.csv
# ├── metals/
# │   ├── XAUUSD/
# │   │   ├── 1D/
# │   │   │   ├── XAUUSD_1D_ASK.csv
# │   │   │   ├── XAUUSD_1D_BID.csv
# │   │   ├── 1H/
# │   │   │   ├── XAUUSD_1H_ASK.csv
# │   │   │   ├── XAUUSD_1H_BID.csv
# │   │   ├── 1M/
# │   │   │   ├── XAUUSD_1M_ASK.csv
# │   │   │   ├── XAUUSD_1M_BID.csv
# │   │   ├── 1W/
# │   │   │   ├── XAUUSD_1W_ASK.csv
# │   │   │   ├── XAUUSD_1W_BID.csv
# │   │   ├── 4H/
# │   │   │   ├── XAUUSD_4H_ASK.csv
# │   │   │   ├── XAUUSD_4H_BID.csv
